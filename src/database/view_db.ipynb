# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('database.db')

# Query all rows from the sensor_data table and load them into a Pandas DataFrame
df_sensor_data = pd.read_sql_query('SELECT * FROM sensor_data', conn)

df_sensor_data  # This will display the DataFrame in a tabular format in Jupyter notebook
# Out:
#                                   sensor_id            timestamp  sensor_value
# 0      8207e432-75c9-42c2-9eec-cf49f9d6414c  2025-05-05 14:00:00           1.0
# 1      058a5dff-4fc9-46c0-8be4-3729db33dc5b  2025-05-05 14:00:00           0.0
# 2      b2a890fa-78ef-481b-a5f4-97354b115c32  2025-05-05 14:00:00           2.0
# 3      c18cf63d-0b43-479c-bd1b-bb87f0b8dd46  2025-05-05 14:00:00           1.0
# 4      90be5261-3292-45af-a03f-0b068bd79870  2025-05-05 14:00:00           0.0
# ...                                     ...                  ...           ...
# 13435  6d109386-8af8-4836-a9e2-16d70db3375d  2025-04-28 14:15:00           0.0
# 13436  a60ae267-ff0c-4637-9120-108fe7653b02  2025-04-28 14:15:00           0.0
# 13437  2848bb73-e318-4b03-ab7a-0dfcb406b07a  2025-04-28 14:15:00           0.0
# 13438  54d440ea-825f-4128-9eea-99a07816584f  2025-04-28 14:15:00           1.0
# 13439  8d2f063a-0748-4d0e-a051-02dc367d4767  2025-04-28 14:15:00           0.0
#
# [13440 rows x 3 columns]

# %%
# Query all rows from the sensors table and load them into a Pandas DataFrame
df_sensor = pd.read_sql_query('SELECT * FROM sensors', conn)
df_sensor
# Out:
#                                       id                 client_id  \
# 0   8207e432-75c9-42c2-9eec-cf49f9d6414c   L-2025.04.19-21.09-0001
# 1   058a5dff-4fc9-46c0-8be4-3729db33dc5b   L-2025.04.19-21.09-0002
# 2   b2a890fa-78ef-481b-a5f4-97354b115c32   L-2025.04.19-21.09-0003
# 3   c18cf63d-0b43-479c-bd1b-bb87f0b8dd46   L-2025.04.19-21.09-0004
# 4   90be5261-3292-45af-a03f-0b068bd79870   L-2025.04.19-21.09-0005
# 5   22d7a53f-dd3b-4b4f-9b61-4ff614512917   L-2025.04.19-21.09-0006
# 6   8a2efdc9-af25-47c7-9c4d-e1506016a687   L-2025.04.19-21.09-0007
# 7   8c0d416f-a8c6-43b4-9f3f-280db17834da   L-2025.04.19-21.09-0008
# 8   178f21be-cf3b-4bb3-9026-b492a5419e43   T-2025.04.19-21.09-0001
# 9   cb464387-c0d1-4d76-966a-6f38604cef09   T-2025.04.19-21.09-0002
# 10  4204a408-8bc4-482a-b777-7726d36cfd69   T-2025.04.19-21.09-0003
# 11  b9a9a214-27e7-44a0-ba16-d5e959e61941   T-2025.04.19-21.09-0004
# 12  7e7cd121-4622-407e-b5d4-41cb3fb163df   R-2025.04.19-21.09-0001
# 13  104fc1cd-a6a3-4624-854e-ed5c9e88a459   R-2025.04.19-21.09-0002
# 14  167f5890-b009-4d16-a48c-319630c242ce   R-2025.04.19-21.09-0003
# 15  6d109386-8af8-4836-a9e2-16d70db3375d   R-2025.04.19-21.09-0004
# 16  a60ae267-ff0c-4637-9120-108fe7653b02   R-2025.04.19-21.09-0005
# 17  2848bb73-e318-4b03-ab7a-0dfcb406b07a   R-2025.04.19-21.09-0006
# 18  54d440ea-825f-4128-9eea-99a07816584f   R-2025.04.19-21.09-0007
# 19  8d2f063a-0748-4d0e-a051-02dc367d4767   R-2025.04.19-21.09-0008
# 20  59b913ba-54b2-4ec2-9ccf-bd58b96a9cf9   D-2025.04.19-21.09-0001
# 21  889974fa-e7ff-4536-908e-f84b14310ae2  SW-2025.04.19-21.09-0001
#
#              name catagory last_val
# 0              l1    light      1.0
# 1              l2    light      1.0
# 2              l3    light      2.0
# 3              l4    light      0.0
# 4              l5    light      2.0
# 5              l6    light      0.0
# 6              l7    light      3.0
# 7              l8    light      0.0
# 8              t1     temp    20.18
# 9              t2     temp    36.36
# 10             t3     temp     33.5
# 11             t4     temp    27.81
# 12             r1    radar      0.0
# 13             r2    radar      1.0
# 14             r3    radar      1.0
# 15             r4    radar      0.0
# 16             r5    radar      0.0
# 17             r6    radar      0.0
# 18             r7    radar      1.0
# 19             r8    radar      0.0
# 20     Front Door     door     None
# 21  LivingRoom TV   switch     None

# %%
# Write and run the SQL query
df_sensor_data_with_names = pd.read_sql_query("""
    SELECT 
        sensors.name AS sensor_name,
        sensor_data.timestamp,
        sensor_data.sensor_value
    FROM sensor_data
    JOIN sensors ON sensors.id = sensor_data.sensor_id
    ORDER BY sensor_data.timestamp
""", conn)

df_sensor_data_with_names
# Out:
#       sensor_name            timestamp  sensor_value
# 0              l1  2025-04-28 14:15:00           1.0
# 1              l2  2025-04-28 14:15:00           1.0
# 2              l3  2025-04-28 14:15:00           2.0
# 3              l4  2025-04-28 14:15:00           0.0
# 4              l5  2025-04-28 14:15:00           2.0
# ...           ...                  ...           ...
# 13435          r4  2025-05-05 14:00:00           1.0
# 13436          r5  2025-05-05 14:00:00           1.0
# 13437          r6  2025-05-05 14:00:00           1.0
# 13438          r7  2025-05-05 14:00:00           0.0
# 13439          r8  2025-05-05 14:00:00           1.0
#
# [13440 rows x 3 columns]

# %%
# Query all predictions
df_predictions = pd.read_sql_query('SELECT * FROM predictions', conn)

df_predictions
# Out:
# Empty DataFrame
# Columns: [id, timestamp, sensor_name, predicted_value, category]
# Index: []

# %%
# Close the connection
conn.close()
