# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('database.db')

# Query all rows from the sensor_data table and load them into a Pandas DataFrame
df_sensor_data = pd.read_sql_query('SELECT * FROM sensor_data', conn)

df_sensor_data  # This will display the DataFrame in a tabular format in Jupyter notebook
# Out:
#                                   sensor_id            timestamp  sensor_value
# 0      3a72a30e-bfb8-4738-9de1-90d87b0ca54e  2025-05-05 15:00:00           2.0
# 1      9196f541-fde0-4389-b045-0bfa75ef1c2b  2025-05-05 15:00:00           0.0
# 2      ac4f099f-c9bc-47c6-9918-e5dde65c1f56  2025-05-05 15:00:00           1.0
# 3      c7d337a9-ed68-48cb-84e3-29392dd3a492  2025-05-05 15:00:00           2.0
# 4      063fa819-3792-43e5-bed4-b15459286d85  2025-05-05 15:00:00           0.0
# ...                                     ...                  ...           ...
# 21281  986e2da3-ba06-4fda-8065-34eef775917f  2025-05-06 14:49:58           0.0
# 21282  d7a63712-3c76-45bc-9a47-6c7e40f48229  2025-05-06 14:49:58           0.0
# 21283  8908017d-4138-4202-8360-1378010f8db3  2025-05-06 14:49:58           1.0
# 21284  b3efa612-50f6-4474-8a89-3b8be4666271  2025-05-06 14:49:58           1.0
# 21285  ed67eb5f-b320-4fbd-b7cb-3241c90606c6  2025-05-06 14:49:58           1.0
#
# [21286 rows x 3 columns]

# %%
# Query all rows from the sensors table and load them into a Pandas DataFrame
df_sensor = pd.read_sql_query('SELECT * FROM sensors', conn)
df_sensor
# Out:
#                                       id                 client_id  \
# 0   3a72a30e-bfb8-4738-9de1-90d87b0ca54e   L-2025.04.19-21.09-0001
# 1   9196f541-fde0-4389-b045-0bfa75ef1c2b   L-2025.04.19-21.09-0002
# 2   ac4f099f-c9bc-47c6-9918-e5dde65c1f56   L-2025.04.19-21.09-0003
# 3   063fa819-3792-43e5-bed4-b15459286d85   L-2025.04.19-21.09-0005
# 4   ffbc9743-e13a-46ae-a352-6caf872645bc   L-2025.04.19-21.09-0006
# 5   c77fed2c-4932-48c6-8940-a1edf7e4cbdf   L-2025.04.19-21.09-0007
# 6   c8854fd6-7525-47c1-9d2c-6d4b3ad9fd70   T-2025.04.19-21.09-0001
# 7   34b3e491-d92e-4fb3-b032-2af72001743e   T-2025.04.19-21.09-0002
# 8   73b413db-48b0-4192-8cae-709b197566ac   T-2025.04.19-21.09-0003
# 9   2607b6af-f8a7-44ec-b919-fa833f5c2092   T-2025.04.19-21.09-0004
# 10  47031ae4-6b46-4943-91c2-8024a0f14adc   R-2025.04.19-21.09-0001
# 11  34d91ca0-f1db-4db7-93b4-50766c7d5ff2   R-2025.04.19-21.09-0002
# 12  181f847b-39f2-4cb6-b538-488385413a58   R-2025.04.19-21.09-0003
# 13  986e2da3-ba06-4fda-8065-34eef775917f   R-2025.04.19-21.09-0004
# 14  d7a63712-3c76-45bc-9a47-6c7e40f48229   R-2025.04.19-21.09-0005
# 15  8908017d-4138-4202-8360-1378010f8db3   R-2025.04.19-21.09-0006
# 16  b3efa612-50f6-4474-8a89-3b8be4666271   R-2025.04.19-21.09-0007
# 17  ed67eb5f-b320-4fbd-b7cb-3241c90606c6   R-2025.04.19-21.09-0008
# 18  89c82c66-ce6f-476e-954d-ccbec0199163   D-2025.04.19-21.09-0001
# 19  7822bc46-5fed-467f-98e9-3aa91901766f  SW-2025.04.19-21.09-0001
#
#              name catagory last_val
# 0              l1    light      0.0
# 1              l2    light      1.0
# 2              l3    light      1.0
# 3              l5    light      2.0
# 4              l6    light      1.0
# 5              l7    light      1.0
# 6              t1     temp    21.22
# 7              t2     temp    24.74
# 8              t3     temp    22.73
# 9              t4     temp    18.77
# 10             r1    radar      1.0
# 11             r2    radar      0.0
# 12             r3    radar      0.0
# 13             r4    radar      0.0
# 14             r5    radar      0.0
# 15             r6    radar      1.0
# 16             r7    radar      1.0
# 17             r8    radar      1.0
# 18     Front Door     door        0
# 19  LivingRoom TV   switch        0

# %%
# Write and run the SQL query
df_sensor_data_with_names = pd.read_sql_query("""
    SELECT 
        sensors.name AS sensor_name,
        sensor_data.timestamp,
        sensor_data.sensor_value
    FROM sensor_data
    JOIN sensors ON sensors.id = sensor_data.sensor_id
    ORDER BY sensor_data.timestamp
""", conn)

df_sensor_data_with_names
# Out:
#       sensor_name            timestamp  sensor_value
# 0              l1  2025-04-28 15:15:00           0.0
# 1              l2  2025-04-28 15:15:00           2.0
# 2              l3  2025-04-28 15:15:00           3.0
# 3              l5  2025-04-28 15:15:00           3.0
# 4              l6  2025-04-28 15:15:00           0.0
# ...           ...                  ...           ...
# 19937          r4  2025-05-06 14:49:58           0.0
# 19938          r5  2025-05-06 14:49:58           0.0
# 19939          r6  2025-05-06 14:49:58           1.0
# 19940          r7  2025-05-06 14:49:58           1.0
# 19941          r8  2025-05-06 14:49:58           1.0
#
# [19942 rows x 3 columns]

# %%
# Query all predictions
df_predictions = pd.read_sql_query('SELECT * FROM predictions', conn)

df_predictions
# Out:
#    id            timestamp sensor_name  predicted_value category
# 0  61  2025-05-05 20:08:57          l1             1.00    light
# 1  62  2025-05-05 20:08:57          l2             2.00    light
# 2  63  2025-05-05 20:08:57          l3             2.00    light
# 3  64  2025-05-05 20:08:57          l5             2.00    light
# 4  65  2025-05-05 20:08:57          l6             1.00    light
# 5  66  2025-05-05 20:08:57          l7             2.00    light
# 6  67  2025-05-05 20:08:57          t1            20.15     temp
# 7  68  2025-05-05 20:08:57          t2            19.19     temp
# 8  69  2025-05-05 20:08:57          t3            20.37     temp
# 9  70  2025-05-05 20:08:57          t4            19.84     temp

# %%
# Close the connection
conn.close()
